# %% [markdown]
# # JUEGO DEL AHORCADO
#
# - Reglas del juego del "Ahorcado":
#
#     - Un jugador elige una palabra secreta y dibuja un espacio para cada letra de la palabra.
#
#     - El otro jugador intenta adivinar letras para completar la palabra.
#
#     - Si el jugador adivinador adivina una letra correctamente, se revela en su lugar correspondiente.
#
#     - Si el jugador adivinador adivina incorrectamente, se dibuja una parte del cuerpo en la horca.
#
#     - El objetivo del jugador adivinador es adivinar la palabra antes de que se dibuje el dibujo completo en la horca.

# %%
#INPUT PALABRA, DIVIDIR CADA CARACTER EN LISTA, CREAR LÑISTA CON EL MISMO NUMERO DE ESPACIOS (?)
# validacion minuscula, sin espacios isalpha (sin simbolos)
# clase con self vidas 
# dibujos corresponden con self vidas
#input jugador letras de 1 en 1 len ==1 / for enumerate /while playing vidas = 0 and "_"
#Master que lance los metodos

#dificultad *facil = 8 vidas * dficil = 6 vidas  y nueva biblioteca
#contra jugador 1 o la maquina (añadir random)

# %%
#Imágenes del ahorcado: 
# #fuente: chrishorton/hangmanwordbank.py

imagenes = [ r'''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''', r'''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', r'''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', r'''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', r'''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', r'''
  +---+
  |   |
  O   |
      |
      |
      |
=========''', r'''
  +---+
  |   |
      |
      |
      |
      |
=========''', r'''
      +
      |
      |
      |
      |
      |
=========''', r'''
      
      
      
      
      
      
========='''  ]

# %%
import random

# %%
class JuegoAhorcado: 
    def __init__(self):
        self.palabra_secreta = "" #Variable donde se introduce la palabra del Jugador1.
        self.espacios = [] #Convertimos a lista de espacios.
        self.vidas = 8 #Vidas máximas por partida.
        self.letras_usadas = [] #Letras ya usadas, para no repetir.
        self.biblioteca = ["canguro", "destino", "sobremesa", "carruaje", "arrebatar", "pescuezo", "columpiar", "bostezar", "mueca", "titubear", "monigote", "arañazo", "peluche", "elefante", "escorpion", "ventana", "biblioteca", "cucaracha", "tortuga", "mariposa", "televisor", "paraguas", "telefono", "ordenador", "camiseta", "escritorio"]
        self.dificil = ["kiwi", "vortice", "azahar", "boxeo", "filigrana", "zurdo", "cuchicheo", "jirafa", "ametralladora"]

    #Elige dificultad:
    def elegir_dificultad(self):
        print ("Elige nivel de juego: fácil o difícil.")
        dificultad = input ("Elige <difícil> para jugar con menos vidas o enter para continuar.").lower().strip()
        if dificultad == "dificil" or dificultad == "difícil":
            self.vidas = 6
            self.biblioteca = self.dificil
            print ("Has elegido modo difícil.")
        else:
            print ("Has elegido modo fácil.")

    #Elige jugar solo o con un amigo. Jugador 1 Introduce la palabra secreta.
    def definir_palabra(self):
        print ("¿Cómo quieres jugar? Solo (1) o contra un amigo (2)")
        eleccion = input ("Elige 1 para jugar solo o 2 para jugar contra un amigo")
        
        if eleccion == "1":
            print (f"Has elegido solo.")
            self.palabra_secreta = random.choice(self.biblioteca)
            self.espacios = ["_"] * len(self.palabra_secreta)
            print("La máquina ha elegido una palabra. ¡Adivínala!")
            return "1"
            
        elif eleccion == "2":
            print (f"Has elegido contra un amigo.")
            while True:
                entrada_provisional = input("Jugador 1 introduce palabra secreta. Escribe <salir> para volver atrás").lower().strip()
                if entrada_provisional == "salir":
                    self.definir_palabra()
                    break

                elif entrada_provisional.isalpha(): #Solo se admiten letras y palabras sin espacios.
                    self.palabra_secreta = entrada_provisional
                    self.espacios = ["_"] * len(self.palabra_secreta) #Para imprimir durante el juego.
                    print ("Palabra guardada. Turno del Jugador 2.")
                    return "2" 

                else: 
                    print ("Palabra no válida. Por favor introduce solo letras sin espacios o símbolos.")
        
        else:
            return None

    #Jugador2 Introduce letras para acertar.
    def pedir_letra(self): 
        while True:
            letra = input ("Introduce una letra o escribe <rendirse> si quieres dejar de jugar").lower().strip()
            if letra == "rendirse":
                return None
            elif len (letra) != 1: #Validación de solo una letra.
                print ("Por favor, introduce una sola letra.")
            elif not letra.isalpha(): #Validación que no sean símbolos o números.
                print ("Por favor, introduce un caracter válido. Solo letras.")
            elif letra in self.letras_usadas: #Validación para evitar letras ya usadas.
                print ("¡Letra ya usada!. Sigue probando.")
            else:
                self.letras_usadas.append(letra) #Añadimos a lista de usadas.
                return letra #Devolvemos el valor de letras para el siguiente apartado.
            
    #El sistema comprueba si la letra existe en la palabra:
    def verificar_letra(self, letra_recibida):
        acierto = False
        for indice, letra in enumerate(self.palabra_secreta):
            if letra == letra_recibida: 
                acierto = True
                self.espacios[indice] = letra_recibida
        if acierto:
            print (f"¡Has acertado! <{letra_recibida}> está en la palabra.")
        else:
            self.vidas -= 1
            print (f"Lo siento. <{letra_recibida}> no está en la palabra.")
            print (f"A tu ahorcado le quedan {self.vidas} vidas.")

    #Máster que controla el resto de métodos y une todo:
    def jugar (self):
        #--------Restart----------:
        self.vidas = 8
        self.letras_usadas = []
        self.espacios = []
        self.biblioteca = ["canguro", "destino", "sobremesa", "carruaje", "arrebatar", "pescuezo", "columpiar", "bostezar", "mueca", "titubear", "monigote", "arañazo", "peluche", "elefante", "escorpion", "ventana", "biblioteca", "cucaracha", "tortuga", "mariposa", "televisor", "paraguas", "telefono", "ordenador", "camiseta", "escritorio"]
        #-------------------------
        
        #Elegir dificultad
        self.elegir_dificultad ()

        #Jugador1 o máquina elige la palabra:
        eleccion_jugador = self.definir_palabra()  
        if eleccion_jugador is None:
            print("El jugador ha cancelado el juego.")
            return 
        
            #Bucle para el Jugador2:
        while self.vidas > 0 and "_" in self.espacios: #se tienen que cumplir ambas, por eso and y no or.
            print (imagenes[self.vidas]) #Imprime la imagen que corresponde al número de vidas.
            print (" ".join (self.espacios).capitalize())
            print ("Ya has probado: " + ", ".join(self.letras_usadas))
                
            letra_recibida = self.pedir_letra ()
            if letra_recibida == None:
                print ("¡Te has rendido!")
                break

            else:
                self.verificar_letra (letra_recibida)

        if "_" not in self.espacios:
            print (" ".join (self.espacios).capitalize())
            print (f"¡Enhorabuena! Has acertado la palabra era <{self.palabra_secreta.title()}>.")
        else:
            print (imagenes[0])
            print (f"¡GAME OVER! La palabra era <{self.palabra_secreta.title()}>.")

# %%
Jugador1 = JuegoAhorcado()

# %%
Jugador1.definir_palabra()

# %%
#TEST PARA COMPROBAR QUE LOS MÉTODOS PARA EL JUGADOR 1 FUNCIONAN.
print(f"Palabra secreta guardada: {Jugador1.palabra_secreta}")
print(f"Lista de espacios generada: {Jugador1.espacios}")
print(f"Vidas iniciales: {Jugador1.vidas}")

# %%
Jugador2 = JuegoAhorcado ()

# %%
Jugador2.pedir_letra()

# %%
print(f"Letras guardadas: {Jugador2.letras_usadas}")

# %%
mi_partida = JuegoAhorcado()

# %%
mi_partida.jugar()
# Out:
# Elige nivel de juego: fácil o difícil.
# Has elegido modo fácil.
# ¿Cómo quieres jugar? Solo (1) o contra un amigo (2)
# Has elegido solo.
# La máquina ha elegido una palabra. ¡Adivínala!
#
#
#
#
#
#
#
# ...
# _ _ _ _ _ _ _ _ _
# Ya has probado:
# Lo siento. <p> no está en la palabra.
# A tu ahorcado le quedan 7 vidas.
#
#       +
#       |
#       |
#       |
#       |
#       |
# ...
# _ _ _ _ _ _ _ _ _
# Ya has probado: p
# ¡Has acertado! <a> está en la palabra.
#
#       +
#       |
#       |
#       |
#       |
#       |
# ...
# A _ _ _ _ a _ a _
# Ya has probado: p, a
# Lo siento. <m> no está en la palabra.
# A tu ahorcado le quedan 6 vidas.
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
# A _ _ _ _ a _ a _
# Ya has probado: p, a, m
# ¡Has acertado! <e> está en la palabra.
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
# A _ _ e _ a _ a _
# Ya has probado: p, a, m, e
# ¡Has acertado! <r> está en la palabra.
#
#   +---+
#   |   |
#       |
#       |
#       |
# ...
